# %% [markdown]
# # Route 55,  6pm-6am Overnight (outbound), Monday-Friday, January - July

# %% [markdown]
#     'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import numpy as np
import re

# %%
with open('WeGo.json') as fi:
    credentials = json.load(fi)

# %%
credentials
Authorization = credentials['Authorization']

# %%
def concat_frames(geo_response, response):
    #This function pulls in two API requests, puts one in a geodataframe the other in a dataframe and concats desired columns
    geo_df = gpd.GeoDataFrame.from_features(geo_response.json()['features'])
    res_df = pd.DataFrame(response.json()['data']['segments'])
    full_df = pd.concat([geo_df, res_df[['countForSegment', 'percent20Secs']]], axis = 1)
    return full_df

# %% [markdown]
# # Jan-Feb 01-25-2022 -> 02-24-2022 6pm -> midnight

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '01-25-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '02-24-2022',
    'endTime' : '23:59',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '01-25-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '02-24-2022',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe1 =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe1 = route_55_zoe1.loc[route_55_zoe1['pathLengthMeters'] > 0]
route_55_zoe1 = route_55_zoe1.loc[route_55_zoe1['countForSegment'] > route_55_zoe1['countForSegment'].max()/2]
route_55_zoe1 = route_55_zoe1.loc[route_55_zoe1['percent20Secs'] >= route_55_zoe1.percent20Secs.quantile(0.80)]
route_55_zoe1 = route_55_zoe1.loc[route_55_zoe1['fromStopId'] != 'ARTS']
route_55_zoe1.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # Jan-Feb 01-25-2022 -> 02-24-2022 Midnight -> 6am

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '01-25-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '02-24-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '01-25-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '02-24-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe1b =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe1b = route_55_zoe1b.loc[route_55_zoe1b['pathLengthMeters'] > 0]
route_55_zoe1b = route_55_zoe1b.loc[route_55_zoe1b['countForSegment'] > route_55_zoe1b['countForSegment'].max()/2]
route_55_zoe1b = route_55_zoe1b.loc[route_55_zoe1b['percent20Secs'] >= route_55_zoe1b.percent20Secs.quantile(0.80)]
route_55_zoe1b = route_55_zoe1b.loc[route_55_zoe1b['fromStopId'] != 'ARTS']
route_55_zoe1b.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # Feb - March 02-25-2022 -> 03-26-2022 6pm -> Midnight

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '02-25-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '03-26-2022',
    'endTime' : '23:59',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '02-25-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '03-26-2022',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe2 =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe2 = route_55_zoe2.loc[route_55_zoe2['pathLengthMeters'] > 0]
route_55_zoe2 = route_55_zoe2.loc[route_55_zoe2['countForSegment'] > route_55_zoe2['countForSegment'].max()/2]
route_55_zoe2 = route_55_zoe2.loc[route_55_zoe2['percent20Secs'] >= route_55_zoe2.percent20Secs.quantile(0.80)]
route_55_zoe2 = route_55_zoe2.loc[route_55_zoe2['fromStopId'] != 'ARTS']
route_55_zoe2.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # Feb - March 02-25-2022 -> 03-26-2022 Midnight -> 6am

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '02-25-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '03-26-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '02-25-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '03-26-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe2b =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe2b = route_55_zoe2b.loc[route_55_zoe2b['pathLengthMeters'] > 0]
route_55_zoe2b = route_55_zoe2b.loc[route_55_zoe2b['countForSegment'] > route_55_zoe2b['countForSegment'].max()/2]
route_55_zoe2b = route_55_zoe2b.loc[route_55_zoe2b['percent20Secs'] >= route_55_zoe2b.percent20Secs.quantile(0.80)]
route_55_zoe2b = route_55_zoe2b.loc[route_55_zoe2b['fromStopId'] != 'ARTS']
route_55_zoe2b.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # March - April 03-27-2022 -> 04-26-2022 6pm -> Midnight

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '03-27-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '04-26-2022',
    'endTime' : '23:59',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '03-27-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '04-26-2022',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe3 =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe3 = route_55_zoe3.loc[route_55_zoe3['pathLengthMeters'] > 0]
route_55_zoe3 = route_55_zoe3.loc[route_55_zoe3['countForSegment'] > route_55_zoe3['countForSegment'].max()/2]
route_55_zoe3 = route_55_zoe3.loc[route_55_zoe3['percent20Secs'] >= route_55_zoe3.percent20Secs.quantile(0.80)]
route_55_zoe3 = route_55_zoe3.loc[route_55_zoe3['fromStopId'] != 'ARTS']
route_55_zoe3.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # March - April 03-27-2022 -> 04-26-2022 Midnight -> 6am

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '03-27-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '04-26-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '03-27-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '04-26-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe3b =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe3b = route_55_zoe3b.loc[route_55_zoe3b['pathLengthMeters'] > 0]
route_55_zoe3b = route_55_zoe3b.loc[route_55_zoe3b['countForSegment'] > route_55_zoe3b['countForSegment'].max()/2]
route_55_zoe3b = route_55_zoe3b.loc[route_55_zoe3b['percent20Secs'] >= route_55_zoe3b.percent20Secs.quantile(0.80)]
route_55_zoe3b = route_55_zoe3b.loc[route_55_zoe3b['fromStopId'] != 'ARTS']
route_55_zoe3b.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # April - May 04-27-2022 -> 05-25-2022 6pm -> Midnight

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '04-27-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '23:59',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '04-27-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe4 =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe4 = route_55_zoe4.loc[route_55_zoe4['pathLengthMeters'] > 0]
route_55_zoe4 = route_55_zoe4.loc[route_55_zoe4['countForSegment'] > route_55_zoe4['countForSegment'].max()/2]
route_55_zoe4 = route_55_zoe4.loc[route_55_zoe4['percent20Secs'] >= route_55_zoe4.percent20Secs.quantile(0.80)]
route_55_zoe4 = route_55_zoe4.loc[route_55_zoe4['fromStopId'] != 'ARTS']
route_55_zoe4.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # April - May 04-27-2022 -> 05-25-2022 Midnight - 6pm

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '04-27-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '04-27-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '05-25-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe4b =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe4b = route_55_zoe4b.loc[route_55_zoe4b['pathLengthMeters'] > 0]
route_55_zoe4b = route_55_zoe4b.loc[route_55_zoe4b['countForSegment'] > route_55_zoe4b['countForSegment'].max()/2]
route_55_zoe4b = route_55_zoe4b.loc[route_55_zoe4b['percent20Secs'] >= route_55_zoe4b.percent20Secs.quantile(0.80)]
route_55_zoe4b = route_55_zoe4b.loc[route_55_zoe4b['fromStopId'] != 'ARTS']
route_55_zoe4b.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # May - June 05-26-2022 -> 06-25-2022 6pm -> Midnight

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '05-26-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '06-25-2022',
    'endTime' : '23:59',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '05-26-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '06-25-2022',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe5 =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe5 = route_55_zoe5.loc[route_55_zoe5['pathLengthMeters'] > 0]
route_55_zoe5 = route_55_zoe5.loc[route_55_zoe5['countForSegment'] > route_55_zoe5['countForSegment'].max()/2]
route_55_zoe5 = route_55_zoe5.loc[route_55_zoe5['percent20Secs'] >= route_55_zoe5.percent20Secs.quantile(0.80)]
route_55_zoe5 = route_55_zoe5.loc[route_55_zoe5['fromStopId'] != 'ARTS']
route_55_zoe5.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # May - June 05-26-2022 -> 06-25-2022 Midnight -> 6am

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '05-26-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '06-25-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '05-26-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '06-25-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe5b =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe5b = route_55_zoe5b.loc[route_55_zoe5b['pathLengthMeters'] > 0]
route_55_zoe5b = route_55_zoe5b.loc[route_55_zoe5b['countForSegment'] > route_55_zoe5b['countForSegment'].max()/2]
route_55_zoe5b = route_55_zoe5b.loc[route_55_zoe5b['percent20Secs'] >= route_55_zoe5b.percent20Secs.quantile(0.80)]
route_55_zoe5b = route_55_zoe5b.loc[route_55_zoe5b['fromStopId'] != 'ARTS']
route_55_zoe5b.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # June - July 06-26-2022 -> -7-26-2022 6pm -> Midnight

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '06-26-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '07-26-2022',
    'endTime' : '23:59',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '06-26-2022',
    'beginTime' : '18:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '07-26-2022',
    'endTime' : '23:59',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe6 =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe6 = route_55_zoe6.loc[route_55_zoe6['pathLengthMeters'] > 0]
route_55_zoe6 = route_55_zoe6.loc[route_55_zoe6['countForSegment'] > route_55_zoe6['countForSegment'].max()/2]
route_55_zoe6 = route_55_zoe6.loc[route_55_zoe6['percent20Secs'] >= route_55_zoe6.percent20Secs.quantile(0.80)]
route_55_zoe6 = route_55_zoe6.loc[route_55_zoe6['fromStopId'] != 'ARTS']
route_55_zoe6.sort_values('percent20Secs', ascending = False).head()

# %% [markdown]
# # June - July 06-26-2022 -> -7-26-2022 Midnight -> 6am

# %%
URL = 'https://api.goswift.ly/speed-map/nashville/route/55'

params = {
    'direction': '0',
    'startDate': '06-26-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '07-26-2022',
    'endTime' : '06:00',
    'format' : 'geojson',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}


params1 = {
    'direction': '0',
    'startDate': '06-26-2022',
    'beginTime' : '00:00',
    'daysOfWeek' : '1,2,3,4,5',
    'endDate' : '07-26-2022',
    'endTime' : '06:00',
    'resolution': 'hiRes',
    'excludeDates': '01-17-2022,02-18-2022,03-14-2022,03-15-2022,03-16-2022,03-17-2022,03-18-2022,04-14-2022,04-15-2022,05-30-2022,07-04-2022',
}

headers = {'Authorization': Authorization,
          'Content-Type': 'application/json'}

route_55_zoe6b =  concat_frames(requests.get(URL, params = params, headers = headers), requests.get(URL, params = params1, headers = headers))
route_55_zoe6b = route_55_zoe6b.loc[route_55_zoe6b['pathLengthMeters'] > 0]
route_55_zoe6b = route_55_zoe6b.loc[route_55_zoe6b['countForSegment'] > route_55_zoe6b['countForSegment'].max()/2]
route_55_zoe6b = route_55_zoe6b.loc[route_55_zoe6b['percent20Secs'] >= route_55_zoe6b.percent20Secs.quantile(0.80)]
route_55_zoe6b = route_55_zoe6b.loc[route_55_zoe6b['fromStopId'] != 'ARTS']
route_55_zoe6b.sort_values('percent20Secs', ascending = False).head()

# %%
top_overnight = concat(route_55_zoe1, route_55_zoe1b, route_55_zoe2, route_55_zoe2b, route_55_zoe3, route_55_zoe3b,route_55_zoe4, route_55_zoe4b, route_55_zoe5, route_55_zoe5b, route_55_zoe6, route_55_zoe6b)
